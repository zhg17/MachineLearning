# %% [markdown]
# # UFC Data Analysis & Prediction

# %% [markdown]
# ## Introduction

# %%
import pandas as pd
raw_data = pd.read_csv('data.csv',sep = ",")

raw_data.dropna(how="any", axis = 0, inplace = True)
raw_data = raw_data.reset_index()

#remove all columns that contain data about each fighters previous opponents
opponents_col = []

for column in raw_data: 
    if 'opp' in column:
        opponents_col.append(column)

raw_data.drop(opponents_col, axis=1, inplace = True)


#no need to track the subtype of decision victories
red_list = ['R_win_by_Decision_Majority', 'R_win_by_Decision_Split','R_win_by_Decision_Unanimous']
blue_list = ['B_win_by_Decision_Majority', 'B_win_by_Decision_Split','B_win_by_Decision_Unanimous']

raw_data['R_win_by_Decision'] = raw_data[red_list].sum(axis=1)
raw_data['B_win_by_Decision'] = raw_data[blue_list].sum(axis=1)

raw_data.drop(red_list, axis=1, inplace = True)
raw_data.drop(blue_list, axis=1, inplace = True)

#remove the column 'number of rounds', we are predicting based on past data, not current data
raw_data.drop(['no_of_rounds'], axis=1, inplace = True)

#total rounds fought and total time fought both essentially measure the same feature
raw_data.drop(['B_total_time_fought(seconds)', 'R_total_time_fought(seconds)'], axis=1, inplace = True)

#idk wether to remove these or not
#PASS is no. times the guard was passed, REV is the no. of Reversals landed (seem like too specific stats)
to_remove = ['R_avg_PASS', 'B_avg_PASS', 'R_avg_REV', 'B_avg_REV']

#significant strikes landed and attempted are further broken down into subcategories by
#body part : BODY, LEG, HEAD and distance: CLINCH, GROUND, DISTANCE
#I think that this is unnecessary

to_remove.extend([
    'B_avg_BODY_att', 'B_avg_BODY_landed','R_avg_BODY_att', 'R_avg_BODY_landed',
    'B_avg_LEG_att', 'B_avg_LEG_landed', 'R_avg_LEG_att', 'R_avg_LEG_landed',
    'B_avg_HEAD_att', 'B_avg_HEAD_landed', 'R_avg_HEAD_att', 'R_avg_HEAD_landed'
    ])

to_remove.extend([
    'B_avg_CLINCH_att', 'B_avg_CLINCH_landed','R_avg_CLINCH_att', 'R_avg_CLINCH_landed',
    'B_avg_GROUND_att', 'B_avg_GROUND_landed', 'R_avg_GROUND_att', 'R_avg_GROUND_landed',
    'B_avg_DISTANCE_att', 'B_avg_DISTANCE_landed', 'R_avg_DISTANCE_att', 'R_avg_DISTANCE_landed'
    ])

raw_data.drop(to_remove, axis=1, inplace = True)

#create new column for average total strikes percentage landed
blue_total_att = raw_data['B_avg_TOTAL_STR_att']
blue_total_landed = raw_data['B_avg_TOTAL_STR_landed']
red_total_att = raw_data['R_avg_TOTAL_STR_att']
red_total_landed = raw_data['R_avg_TOTAL_STR_landed']
blue_total_pct = []
red_total_pct = []

for i in range(len(blue_total_att)):
    att = blue_total_att[i]
    landed = blue_total_landed[i]
    if (att == 0):
        blue_total_pct.append(0)
    else:
        blue_total_pct.append(landed / att)

for i in range(len(red_total_att)):
    att = red_total_att[i]
    landed = red_total_landed[i]
    if (att == 0):
        red_total_pct.append(0)
    else:
        red_total_pct.append(landed / att)

raw_data['B_avg_TOTAL_STR_pct'] = blue_total_pct
raw_data['R_avg_TOTAL_STR_pct'] = red_total_pct

#check
print(raw_data)
for column in raw_data:
    print(column)
# Out:
#       index             R_fighter        B_fighter          Referee  \
# 0         0          Henry Cejudo    Marlon Moraes     Marc Goddard
# 1         1  Valentina Shevchenko      Jessica Eye  Robert Madrigal
# 2         2         Tony Ferguson   Donald Cerrone  Dan Miragliotta
# 3         3         Jimmie Rivera         Petr Yan  Kevin MacDonald
# 4         4           Tai Tuivasa    Blagoy Ivanov  Dan Miragliotta
# ...     ...                   ...              ...              ...
# 3197   4887            Tito Ortiz      Evan Tanner    John McCarthy
# 3198   4901         Chuck Liddell      Jeff Monson   Mario Yamasaki
# 3199   4923            Tito Ortiz  Wanderlei Silva    John McCarthy
# 3200   4967           Jeremy Horn    Chuck Liddell    John McCarthy
# 3201   5008         Randy Couture    Vitor Belfort    John McCarthy
#
#             date                         location Winner  title_bout  \
# 0     2019-06-08           Chicago, Illinois, USA    Red        True
# 1     2019-06-08           Chicago, Illinois, USA    Red        True
# 2     2019-06-08           Chicago, Illinois, USA    Red       False
# 3     2019-06-08           Chicago, Illinois, USA   Blue       False
# 4     2019-06-08           Chicago, Illinois, USA   Blue       False
# ...          ...                              ...    ...         ...
# 3197  2001-02-23   Atlantic City, New Jersey, USA    Red        True
# 3198  2000-12-16                     Tokyo, Japan    Red       False
# 3199  2000-04-14                     Tokyo, Japan    Red        True
# 3200  1999-03-05  Bay St. Louis, Mississippi, USA    Red       False
# 3201  1997-10-17  Bay St. Louis, Mississippi, USA    Red       False
#
#            weight_class  B_current_lose_streak  ...  R_Stance  R_Height_cms  \
# 0          Bantamweight                    0.0  ...  Orthodox        162.56
# 1     Women's Flyweight                    0.0  ...  Southpaw        165.10
# 2           Lightweight                    0.0  ...  Orthodox        180.34
# 3          Bantamweight                    0.0  ...  Orthodox        162.56
# 4           Heavyweight                    0.0  ...  Southpaw        187.96
# ...                 ...                    ...  ...       ...           ...
# 3197  Light Heavyweight                    0.0  ...  Orthodox        190.50
# 3198       Middleweight                    0.0  ...  Orthodox        187.96
# 3199  Light Heavyweight                    0.0  ...  Orthodox        190.50
# 3200       Middleweight                    0.0  ...  Orthodox        185.42
# 3201        Heavyweight                    0.0  ...  Orthodox        185.42
#
#       R_Reach_cms  R_Weight_lbs  B_age  R_age  R_win_by_Decision  \
# 0          162.56         135.0   31.0   32.0                6.0
# 1          167.64         125.0   32.0   31.0                3.0
# 2          193.04         155.0   36.0   35.0                4.0
# 3          172.72         135.0   26.0   29.0                5.0
# 4          190.50         264.0   32.0   26.0                1.0
# ...           ...           ...    ...    ...                ...
# 3197       187.96         205.0   30.0   26.0                1.0
# 3198       193.04         205.0   29.0   30.0                1.0
# 3199       187.96         205.0   23.0   25.0                0.0
# 3200       187.96         185.0   29.0   23.0                0.0
# 3201       190.50         205.0   20.0   34.0                0.0
#
#       B_win_by_Decision  B_avg_TOTAL_STR_pct  R_avg_TOTAL_STR_pct
# 0                   1.0             0.355422             0.531948
# 1                   3.0             0.438563             0.636605
# 2                   7.0             0.506687             0.476692
# 3                   2.0             0.560582             0.432375
# 4                   1.0             0.303922             0.515748
# ...                 ...                  ...                  ...
# 3197                0.0             0.751938             0.708126
# 3198                1.0             0.762500             0.624434
# 3199                0.0             0.804878             0.662500
# 3200                1.0             0.521368             0.788732
# 3201                0.0             0.666667             0.896552
#
# [3202 rows x 63 columns]
# index
# R_fighter
# B_fighter
# Referee
# date
# location
# Winner
# title_bout
# weight_class
# B_current_lose_streak
# B_current_win_streak
# B_draw
# B_avg_KD
# B_avg_SIG_STR_att
# B_avg_SIG_STR_landed
# B_avg_SIG_STR_pct
# B_avg_SUB_ATT
# B_avg_TD_att
# B_avg_TD_landed
# B_avg_TD_pct
# B_avg_TOTAL_STR_att
# B_avg_TOTAL_STR_landed
# B_longest_win_streak
# B_losses
# B_total_rounds_fought
# B_total_title_bouts
# B_win_by_KO/TKO
# B_win_by_Submission
# B_wins
# B_Stance
# B_Height_cms
# B_Reach_cms
# B_Weight_lbs
# R_current_lose_streak
# R_current_win_streak
# R_draw
# R_avg_KD
# R_avg_SIG_STR_att
# R_avg_SIG_STR_landed
# R_avg_SIG_STR_pct
# R_avg_SUB_ATT
# R_avg_TD_att
# R_avg_TD_landed
# R_avg_TD_pct
# R_avg_TOTAL_STR_att
# R_avg_TOTAL_STR_landed
# R_longest_win_streak
# R_losses
# R_total_rounds_fought
# R_total_title_bouts
# R_win_by_KO/TKO
# R_win_by_Submission
# R_wins
# R_Stance
# R_Height_cms
# R_Reach_cms
# R_Weight_lbs
# B_age
# R_age
# R_win_by_Decision
# B_win_by_Decision
# B_avg_TOTAL_STR_pct
# R_avg_TOTAL_STR_pct

# %%
# Cleaning the Winner column (red fighter = 1; blue fighter = 0)
new_winners = []

raw_data = raw_data[raw_data['Winner'] != 'Draw']

raw_data = raw_data.reset_index()

winners = raw_data['Winner']

for i in range(0, len(winners)):
    if ("Red" == winners[i]):
        new_winners.append(1)
    elif ("Blue" == winners[i]):
        new_winners.append(0)

raw_data['Winner'] = new_winners

# %%
raw_data
# Out:
#       level_0  index             R_fighter        B_fighter          Referee  \
# 0           0      0          Henry Cejudo    Marlon Moraes     Marc Goddard
# 1           1      1  Valentina Shevchenko      Jessica Eye  Robert Madrigal
# 2           2      2         Tony Ferguson   Donald Cerrone  Dan Miragliotta
# 3           3      3         Jimmie Rivera         Petr Yan  Kevin MacDonald
# 4           4      4           Tai Tuivasa    Blagoy Ivanov  Dan Miragliotta
# ...       ...    ...                   ...              ...              ...
# 3146     3197   4887            Tito Ortiz      Evan Tanner    John McCarthy
# 3147     3198   4901         Chuck Liddell      Jeff Monson   Mario Yamasaki
# 3148     3199   4923            Tito Ortiz  Wanderlei Silva    John McCarthy
# 3149     3200   4967           Jeremy Horn    Chuck Liddell    John McCarthy
# 3150     3201   5008         Randy Couture    Vitor Belfort    John McCarthy
#
#             date                         location  Winner  title_bout  \
# 0     2019-06-08           Chicago, Illinois, USA       1        True
# 1     2019-06-08           Chicago, Illinois, USA       1        True
# 2     2019-06-08           Chicago, Illinois, USA       1       False
# 3     2019-06-08           Chicago, Illinois, USA       0       False
# 4     2019-06-08           Chicago, Illinois, USA       0       False
# ...          ...                              ...     ...         ...
# 3146  2001-02-23   Atlantic City, New Jersey, USA       1        True
# 3147  2000-12-16                     Tokyo, Japan       1       False
# 3148  2000-04-14                     Tokyo, Japan       1        True
# 3149  1999-03-05  Bay St. Louis, Mississippi, USA       1       False
# 3150  1997-10-17  Bay St. Louis, Mississippi, USA       1       False
#
#            weight_class  ...  R_Stance  R_Height_cms  R_Reach_cms  \
# 0          Bantamweight  ...  Orthodox        162.56       162.56
# 1     Women's Flyweight  ...  Southpaw        165.10       167.64
# 2           Lightweight  ...  Orthodox        180.34       193.04
# 3          Bantamweight  ...  Orthodox        162.56       172.72
# 4           Heavyweight  ...  Southpaw        187.96       190.50
# ...                 ...  ...       ...           ...          ...
# 3146  Light Heavyweight  ...  Orthodox        190.50       187.96
# 3147       Middleweight  ...  Orthodox        187.96       193.04
# 3148  Light Heavyweight  ...  Orthodox        190.50       187.96
# 3149       Middleweight  ...  Orthodox        185.42       187.96
# 3150        Heavyweight  ...  Orthodox        185.42       190.50
#
#       R_Weight_lbs  B_age  R_age  R_win_by_Decision  B_win_by_Decision  \
# 0            135.0   31.0   32.0                6.0                1.0
# 1            125.0   32.0   31.0                3.0                3.0
# 2            155.0   36.0   35.0                4.0                7.0
# 3            135.0   26.0   29.0                5.0                2.0
# 4            264.0   32.0   26.0                1.0                1.0
# ...            ...    ...    ...                ...                ...
# 3146         205.0   30.0   26.0                1.0                0.0
# 3147         205.0   29.0   30.0                1.0                1.0
# 3148         205.0   23.0   25.0                0.0                0.0
# 3149         185.0   29.0   23.0                0.0                1.0
# 3150         205.0   20.0   34.0                0.0                0.0
#
#       B_avg_TOTAL_STR_pct  R_avg_TOTAL_STR_pct
# 0                0.355422             0.531948
# 1                0.438563             0.636605
# 2                0.506687             0.476692
# 3                0.560582             0.432375
# 4                0.303922             0.515748
# ...                   ...                  ...
# 3146             0.751938             0.708126
# 3147             0.762500             0.624434
# 3148             0.804878             0.662500
# 3149             0.521368             0.788732
# 3150             0.666667             0.896552
#
# [3151 rows x 64 columns]

# %%
#add column for gender
gender = []
weight_class = raw_data['weight_class']

for i in weight_class:
    if 'Women' in i:
        gender.append('F')
    else:
        gender.append('M')

raw_data['Gender'] = gender

raw_data = raw_data.drop(columns=['level_0'])

# %%
raw_data
# Out:
#       index             R_fighter        B_fighter          Referee  \
# 0         0          Henry Cejudo    Marlon Moraes     Marc Goddard
# 1         1  Valentina Shevchenko      Jessica Eye  Robert Madrigal
# 2         2         Tony Ferguson   Donald Cerrone  Dan Miragliotta
# 3         3         Jimmie Rivera         Petr Yan  Kevin MacDonald
# 4         4           Tai Tuivasa    Blagoy Ivanov  Dan Miragliotta
# ...     ...                   ...              ...              ...
# 3146   4887            Tito Ortiz      Evan Tanner    John McCarthy
# 3147   4901         Chuck Liddell      Jeff Monson   Mario Yamasaki
# 3148   4923            Tito Ortiz  Wanderlei Silva    John McCarthy
# 3149   4967           Jeremy Horn    Chuck Liddell    John McCarthy
# 3150   5008         Randy Couture    Vitor Belfort    John McCarthy
#
#             date                         location  Winner  title_bout  \
# 0     2019-06-08           Chicago, Illinois, USA       1        True
# 1     2019-06-08           Chicago, Illinois, USA       1        True
# 2     2019-06-08           Chicago, Illinois, USA       1       False
# 3     2019-06-08           Chicago, Illinois, USA       0       False
# 4     2019-06-08           Chicago, Illinois, USA       0       False
# ...          ...                              ...     ...         ...
# 3146  2001-02-23   Atlantic City, New Jersey, USA       1        True
# 3147  2000-12-16                     Tokyo, Japan       1       False
# 3148  2000-04-14                     Tokyo, Japan       1        True
# 3149  1999-03-05  Bay St. Louis, Mississippi, USA       1       False
# 3150  1997-10-17  Bay St. Louis, Mississippi, USA       1       False
#
#            weight_class  B_current_lose_streak  ...  R_Height_cms  \
# 0          Bantamweight                    0.0  ...        162.56
# 1     Women's Flyweight                    0.0  ...        165.10
# 2           Lightweight                    0.0  ...        180.34
# 3          Bantamweight                    0.0  ...        162.56
# 4           Heavyweight                    0.0  ...        187.96
# ...                 ...                    ...  ...           ...
# 3146  Light Heavyweight                    0.0  ...        190.50
# 3147       Middleweight                    0.0  ...        187.96
# 3148  Light Heavyweight                    0.0  ...        190.50
# 3149       Middleweight                    0.0  ...        185.42
# 3150        Heavyweight                    0.0  ...        185.42
#
#       R_Reach_cms  R_Weight_lbs  B_age  R_age  R_win_by_Decision  \
# 0          162.56         135.0   31.0   32.0                6.0
# 1          167.64         125.0   32.0   31.0                3.0
# 2          193.04         155.0   36.0   35.0                4.0
# 3          172.72         135.0   26.0   29.0                5.0
# 4          190.50         264.0   32.0   26.0                1.0
# ...           ...           ...    ...    ...                ...
# 3146       187.96         205.0   30.0   26.0                1.0
# 3147       193.04         205.0   29.0   30.0                1.0
# 3148       187.96         205.0   23.0   25.0                0.0
# 3149       187.96         185.0   29.0   23.0                0.0
# 3150       190.50         205.0   20.0   34.0                0.0
#
#       B_win_by_Decision  B_avg_TOTAL_STR_pct  R_avg_TOTAL_STR_pct  Gender
# 0                   1.0             0.355422             0.531948       M
# 1                   3.0             0.438563             0.636605       F
# 2                   7.0             0.506687             0.476692       M
# 3                   2.0             0.560582             0.432375       M
# 4                   1.0             0.303922             0.515748       M
# ...                 ...                  ...                  ...     ...
# 3146                0.0             0.751938             0.708126       M
# 3147                1.0             0.762500             0.624434       M
# 3148                0.0             0.804878             0.662500       M
# 3149                1.0             0.521368             0.788732       M
# 3150                0.0             0.666667             0.896552       M
#
# [3151 rows x 64 columns]

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(15,8))
plt.xticks(rotation=45)
ax = sns.countplot(x=raw_data['weight_class'], data=raw_data)

# %%
# Plotting for Number of wins and Fighter colors as UFC puts the favored fighter in the red corners

num_red_wins = 0
num_blue_wins = 0

for i, row in raw_data.iterrows():
    if (row['Winner'] == 1):
        num_red_wins = num_red_wins + 1
    elif (row['Winner'] == 0):
        num_blue_wins = num_blue_wins + 1
        
labels = 'Wins by Red Fighters', 'Wins by Blue Fighters'
sizes = [num_red_wins, num_blue_wins]
colors = ['red', 'blue']
explode = (0, 0.1)

# Plot
plt.figure(figsize=(15,8))
plt.pie(sizes, explode=explode, labels=labels, colors=colors,autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

# %%
men_fights = 0
women_fights = 0

for i, row in raw_data.iterrows():
    if (row['Gender'] == "M"):
        men_fights = men_fights + 1
    elif (row['Gender'] == "F"):
        women_fights = women_fights + 1
        
labels = 'Number of Men Fights', 'Number of Women Fights'
sizes = [men_fights, women_fights]
colors = ['blue', 'pink']
explode = (0, 0.1)

# Plot
plt.figure(figsize=(15,8))
plt.pie(sizes, explode=explode, labels=labels, colors=colors,autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

# %%
title_fights = 0
normal_fights = 0

for i, row in raw_data.iterrows():
    if (row['title_bout'] == True):
        title_fights = title_fights + 1
    elif (row['title_bout'] == False):
        normal_fights = normal_fights + 1
        
labels = 'Number of Title Fights', 'Number of Non-Title Fights'
sizes = [title_fights, normal_fights]
colors = ['gold', 'blue']
explode = (0, 0.1)

# Plot
plt.figure(figsize=(15,8))
plt.pie(sizes, explode=explode, labels=labels, colors=colors,autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(15,8))
ax = sns.scatterplot(x='R_current_win_streak', y='B_current_win_streak', hue='Winner', data=raw_data)

# %%
raw_data.columns
# Out:
# Index(['index', 'R_fighter', 'B_fighter', 'Referee', 'date', 'location',
#        'Winner', 'title_bout', 'weight_class', 'B_current_lose_streak',
#        'B_current_win_streak', 'B_draw', 'B_avg_KD', 'B_avg_SIG_STR_att',
#        'B_avg_SIG_STR_landed', 'B_avg_SIG_STR_pct', 'B_avg_SUB_ATT',
#        'B_avg_TD_att', 'B_avg_TD_landed', 'B_avg_TD_pct',
#        'B_avg_TOTAL_STR_att', 'B_avg_TOTAL_STR_landed', 'B_longest_win_streak',
#        'B_losses', 'B_total_rounds_fought', 'B_total_title_bouts',
#        'B_win_by_KO/TKO', 'B_win_by_Submission', 'B_wins', 'B_Stance',
#        'B_Height_cms', 'B_Reach_cms', 'B_Weight_lbs', 'R_current_lose_streak',
#        'R_current_win_streak', 'R_draw', 'R_avg_KD', 'R_avg_SIG_STR_att',
#        'R_avg_SIG_STR_landed', 'R_avg_SIG_STR_pct', 'R_avg_SUB_ATT',
#        'R_avg_TD_att', 'R_avg_TD_landed', 'R_avg_TD_pct',
#        'R_avg_TOTAL_STR_att', 'R_avg_TOTAL_STR_landed', 'R_longest_win_streak',
#        'R_losses', 'R_total_rounds_fought', 'R_total_title_bouts',
#        'R_win_by_KO/TKO', 'R_win_by_Submission', 'R_wins', 'R_Stance',
#        'R_Height_cms', 'R_Reach_cms', 'R_Weight_lbs', 'B_age', 'R_age',
#        'R_win_by_Decision', 'B_win_by_Decision', 'B_avg_TOTAL_STR_pct',
#        'R_avg_TOTAL_STR_pct', 'Gender'],
#       dtype='object')

# %%
plt.figure(figsize=(15,8))
ax = sns.scatterplot(x='R_wins', y='B_wins', hue='Winner', data=raw_data)

# %%
f_data = pd.read_csv('raw_fighter_details.csv')

plt.figure(figsize=(15,8))

f_data.dropna(how="any", axis = 0, inplace = True)
ax = sns.countplot(x=f_data['Stance'], data=f_data)

# %%
f_data
# Out:
#               fighter_name  Height    Weight Reach    Stance           DOB
# 10          Aaron Phillips   5' 9"  135 lbs.   70"  Southpaw  Aug 05, 1989
# 11             Aaron Riley   5' 8"  155 lbs.   69"  Southpaw  Dec 09, 1980
# 12              Aaron Rosa   6' 4"  205 lbs.   78"  Orthodox  May 28, 1983
# 13           Aaron Simpson   6' 0"  170 lbs.   73"  Orthodox  Jul 20, 1974
# 17    Abdul Razak Alhassan  5' 10"  170 lbs.   73"  Orthodox  Aug 11, 1985
# ...                    ...     ...       ...   ...       ...           ...
# 3304             Zak Ottow  5' 11"  170 lbs.   72"  Orthodox  Dec 22, 1986
# 3308         Zelim Imadaev   6' 0"  170 lbs.   76"  Orthodox  Jan 25, 1995
# 3309          Zhang Lipeng  5' 11"  155 lbs.   71"  Southpaw  Mar 10, 1990
# 3311            Zu Anyanwu   6' 1"  251 lbs.   77"  Orthodox  Aug 05, 1981
# 3312      Zubaira Tukhugov   5' 8"  145 lbs.   68"  Orthodox  Jan 15, 1991
#
# [1485 rows x 6 columns]
